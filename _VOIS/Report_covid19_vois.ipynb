# %%
#importing pandas
import pandas as pd
import numpy as np

# %%
#dataframe 'df' out of covid_19_india.csv dataset
df = pd.read_csv('covid_19_india.csv')
df
# Out:
#          Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1.0  30/01/20  6:00 PM               Kerala                       1
# 1        2.0  31/01/20  6:00 PM               Kerala                       1
# 2        3.0  01/02/20  6:00 PM               Kerala                       2
# 3        4.0  02/02/20  6:00 PM               Kerala                       3
# 4        5.0  03/02/20  6:00 PM               Kerala                       3
# ...      ...       ...      ...                  ...                     ...
# 4597  4598.0  28/07/20  8:00 AM              Tripura                       -
# 4598  4599.0  28/07/20  8:00 AM          Uttarakhand                       -
# 4599  4600.0  28/07/20  8:00 AM        Uttar Pradesh                       -
# 4600  4601.0  28/07/20  8:00 AM          West Bengal                       -
# 4601     NaN       NaN      NaN                  NaN                     NaN
#
# ...

# %%
#Dropping the irrelevant columns
df.drop('Sno', axis=1, inplace=True)
df
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0     30/01/20  6:00 PM               Kerala                       1
# 1     31/01/20  6:00 PM               Kerala                       1
# 2     01/02/20  6:00 PM               Kerala                       2
# 3     02/02/20  6:00 PM               Kerala                       3
# 4     03/02/20  6:00 PM               Kerala                       3
# ...        ...      ...                  ...                     ...
# 4597  28/07/20  8:00 AM              Tripura                       -
# 4598  28/07/20  8:00 AM          Uttarakhand                       -
# 4599  28/07/20  8:00 AM        Uttar Pradesh                       -
# 4600  28/07/20  8:00 AM          West Bengal                       -
# 4601       NaN      NaN                  NaN                     NaN
#
#      ConfirmedForeignNational    Cured  Deaths  Confirmed   Active
# 0                           0      0.0     0.0        1.0      1.0
# ...

# %%
##Dropping the irrelevant columns
df.dropna(axis=1,thresh=1,inplace=True)
df
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0     30/01/20  6:00 PM               Kerala                       1
# 1     31/01/20  6:00 PM               Kerala                       1
# 2     01/02/20  6:00 PM               Kerala                       2
# 3     02/02/20  6:00 PM               Kerala                       3
# 4     03/02/20  6:00 PM               Kerala                       3
# ...        ...      ...                  ...                     ...
# 4597  28/07/20  8:00 AM              Tripura                       -
# 4598  28/07/20  8:00 AM          Uttarakhand                       -
# 4599  28/07/20  8:00 AM        Uttar Pradesh                       -
# 4600  28/07/20  8:00 AM          West Bengal                       -
# 4601       NaN      NaN                  NaN                     NaN
#
#      ConfirmedForeignNational    Cured  Deaths  Confirmed   Active
# 0                           0      0.0     0.0        1.0      1.0
# ...

# %%
#active patients and add a column 'Active' to the dataframe
df['Active'] = df['Confirmed'] - (df['Cured'] + df['Deaths'])
df
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0     30/01/20  6:00 PM               Kerala                       1
# 1     31/01/20  6:00 PM               Kerala                       1
# 2     01/02/20  6:00 PM               Kerala                       2
# 3     02/02/20  6:00 PM               Kerala                       3
# 4     03/02/20  6:00 PM               Kerala                       3
# ...        ...      ...                  ...                     ...
# 4597  28/07/20  8:00 AM              Tripura                       -
# 4598  28/07/20  8:00 AM          Uttarakhand                       -
# 4599  28/07/20  8:00 AM        Uttar Pradesh                       -
# 4600  28/07/20  8:00 AM          West Bengal                       -
# 4601       NaN      NaN                  NaN                     NaN
#
#      ConfirmedForeignNational    Cured  Deaths  Confirmed   Active
# 0                           0      0.0     0.0        1.0      1.0
# ...

# %%
max_state_value = df.groupby('State/UnionTerritory')['Active'].sum()

# %%
#state having current maximum Active patient and noof active patients
max_state_value[max_state_value == max(max_state_value)]
# Out:
# State/UnionTerritory
# Maharashtra    5441638.0
# Name: Active, dtype: float64

# %%
#state/union territory having current minimum Active patient and noof active patients
min_state_value = df.groupby('State/UnionTerritory')['Active'].sum()

# %%
min_state_value[min_state_value == min(min_state_value)]
# Out:
# State/UnionTerritory
# Daman & Diu    2.0
# Name: Active, dtype: float64

# %%
death_to_cure = df.groupby('State/UnionTerritory').sum()
death_to_cure
# Out:
#                                                Sno      Cured    Deaths  \
# State/UnionTerritory
# Andaman and Nicobar Islands               299076.0     5466.0       1.0
# Andhra Pradesh                            302164.0   716878.0   18691.0
# Arunachal Pradesh                         295601.0     6181.0      69.0
# Assam                                     296811.0   429096.0    1446.0
# Bihar                                     300771.0   539437.0    6008.0
# Cases being reassigned to states          191339.0        0.0       0.0
# Chandigarh                                301694.0    24068.0     499.0
# Chhattisgarh                              301716.0   125536.0     849.0
# Dadar Nagar Haveli                         83440.0       14.0       0.0
# Dadra and Nagar Haveli and Daman and Diu  176440.0     8936.0      28.0
# Daman & Diu                                 2891.0        0.0       0.0
# Delhi                                     303611.0  3349493.0  146572.0
# ...

# %%
#Deaths to Cured ratio then find the states having
minimum and maximum ratios
death_to_cure['death/cure'] = death_to_cure['Deaths']/death_to_cure['Cured']
death_to_cure
# Out:
#                                                Sno      Cured    Deaths  \
# State/UnionTerritory
# Andaman and Nicobar Islands               299076.0     5466.0       1.0
# Andhra Pradesh                            302164.0   716878.0   18691.0
# Arunachal Pradesh                         295601.0     6181.0      69.0
# Assam                                     296811.0   429096.0    1446.0
# Bihar                                     300771.0   539437.0    6008.0
# Cases being reassigned to states          191339.0        0.0       0.0
# Chandigarh                                301694.0    24068.0     499.0
# Chhattisgarh                              301716.0   125536.0     849.0
# Dadar Nagar Haveli                         83440.0       14.0       0.0
# Dadra and Nagar Haveli and Daman and Diu  176440.0     8936.0      28.0
# Daman & Diu                                 2891.0        0.0       0.0
# Delhi                                     303611.0  3349493.0  146572.0
# ...

# %%
#Deaths to Cured ratio then find the states having minimum and maximum ratios
death_to_cure[death_to_cure['death/cure'] == max(death_to_cure['death/cure'])]
# Out:
#                            Sno      Cured    Deaths  Confirmed    Active  \
# State/UnionTerritory
# Gujarat               301977.0  1509336.0  123113.0  2303680.0  671231.0
#
#                       death/cure
# State/UnionTerritory
# Gujarat                 0.081568

# %%
#Import matplotlib functions
#pie charts on the last recorded data of both Delhi and
#Maharashtra having labels as 'Active', 'Deaths', 'Cured' with clear
#mention of percentage
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filt = (df['State/UnionTerritory'] == 'Delhi')
df[filt]
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 34    02/03/20  6:00 PM                Delhi                       1
# 38    03/03/20  6:00 PM                Delhi                       1
# 42    04/03/20  6:00 PM                Delhi                       1
# 45    05/03/20  6:00 PM                Delhi                       2
# 51    06/03/20  6:00 PM                Delhi                       3
# ...        ...      ...                  ...                     ...
# 4434  24/07/20  8:00 AM                Delhi                       -
# 4469  25/07/20  8:00 AM                Delhi                       -
# 4504  26/07/20  8:00 AM                Delhi                       -
# 4539  27/07/20  8:00 AM                Delhi                       -
# 4574  28/07/20  8:00 AM                Delhi                       -
#
#      ConfirmedForeignNational     Cured  Deaths  Confirmed   Active
# 34                          0       0.0     0.0        1.0      1.0
# ...

# %%
df[filt]['Cured'].sum()
# Out:
# 3349493.0

# %%
df[filt]['Deaths'].sum()
# Out:
# 146572.0

# %%
df[filt]['Active'].sum()
# Out:
# 1398338.0

# %%
#Pie chart

#Quantities for plotting
condition = ["Deaths","Active","Cured"]
person = [146572.0,1398338.0,3349493.0]

#Defining colors for plot
colors = ["red","orange","blue"]

# Plotting pie chart
plt.pie(person, labels=condition,explode = [0.1,0,0] ,colors=colors,autopct='%1.1f%%', shadow=True, startangle=120)

#Defining the title of our plot
plt.title("Delhi")

#Show what have been plotted
plt.show()

# %%
filt2 = (df['State/UnionTerritory'] == 'Maharashtra')
df[filt2]
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 76    09/03/20  6:00 PM          Maharashtra                       2
# 91    10/03/20  6:00 PM          Maharashtra                       5
# 97    11/03/20  6:00 PM          Maharashtra                       2
# 120   12/03/20  6:00 PM          Maharashtra                      11
# 133   13/03/20  6:00 PM          Maharashtra                      14
# ...        ...      ...                  ...                     ...
# 4445  24/07/20  8:00 AM          Maharashtra                       -
# 4480  25/07/20  8:00 AM          Maharashtra                       -
# 4515  26/07/20  8:00 AM          Maharashtra                       -
# 4550  27/07/20  8:00 AM          Maharashtra                       -
# 4585  28/07/20  8:00 AM          Maharashtra                       -
#
#      ConfirmedForeignNational     Cured   Deaths  Confirmed    Active
# ...

# %%
df[filt2]['Cured'].sum()
# Out:
# 6124046.0

# %%
df[filt2]['Deaths'].sum()
# Out:
# 482203.0

# %%
df[filt2]['Active'].sum()
# Out:
# 5441638.0

# %%
#Pie chart

#Quantities for plotting
condition = ["Deaths","Active","Cured"]
person = [482203.0,5441638.0,6124046.0]

#Defining colors for plot
colors = ["red","orange","blue"]

# Plotting pie chart
plt.pie(person, labels=condition,explode = [0.1,0,0] ,colors=colors,autopct='%1.1f%%', shadow=True, startangle=120)

#Defining the title of our plot
plt.title("Maharashtra")

#Show what have been plotted
plt.show()
